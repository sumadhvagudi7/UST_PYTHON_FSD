# %% [markdown]
# # Heart Disease Interactive Dashboard (Matplotlib + Panel)
#
# Interactive dashboard using Panel and Matplotlib to explore the heart disease dataset.

# %%
pip install panel
# Out:
# Collecting panel
#   Using cached panel-1.8.2-py3-none-any.whl.metadata (15 kB)
# Collecting bleach (from panel)
#   Using cached bleach-6.3.0-py3-none-any.whl.metadata (31 kB)
# Collecting bokeh<3.9.0,>=3.7.0 (from panel)
#   Using cached bokeh-3.8.0-py3-none-any.whl.metadata (10 kB)
# Collecting linkify-it-py (from panel)
#   Using cached linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting markdown (from panel)
#   Using cached markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown-it-py (from panel)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting mdit-py-plugins (from panel)
#   Using cached mdit_py_plugins-0.5.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: packaging in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (25.0)
# Collecting pandas>=1.2 (from panel)
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting param<3.0,>=2.1.0 (from panel)
#   Using cached param-2.2.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting pyviz-comms>=2.0.0 (from panel)
#   Using cached pyviz_comms-3.0.6-py3-none-any.whl.metadata (7.7 kB)
# Collecting requests (from panel)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm (from panel)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions (from panel)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting Jinja2>=2.9 (from bokeh<3.9.0,>=3.7.0->panel)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: contourpy>=1.2 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (1.3.3)
# Collecting narwhals>=1.13 (from bokeh<3.9.0,>=3.7.0->panel)
#   Using cached narwhals-2.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.16 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (2.3.4)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (12.0.0)
# Collecting PyYAML>=3.10 (from bokeh<3.9.0,>=3.7.0->panel)
#   Using cached pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: tornado>=6.2 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (6.5.2)
# Collecting xyzservices>=2021.09.1 (from bokeh<3.9.0,>=3.7.0->panel)
#   Using cached xyzservices-2025.10.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from pandas>=1.2->panel) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.2->panel)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.2->panel)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting webencodings (from bleach->panel)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting uc-micro-py (from linkify-it-py->panel)
#   Using cached uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py->panel)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests->panel)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->panel)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->panel)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->panel)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: colorama in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from tqdm->panel) (0.4.6)
# Collecting MarkupSafe>=2.0 (from Jinja2>=2.9->bokeh<3.9.0,>=3.7.0->panel)
#   Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->panel) (1.17.0)
# Using cached panel-1.8.2-py3-none-any.whl (30.1 MB)
# Using cached bokeh-3.8.0-py3-none-any.whl (7.2 MB)
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached param-2.2.1-py3-none-any.whl (119 kB)
# Using cached pyviz_comms-3.0.6-py3-none-any.whl (84 kB)
# Using cached bleach-6.3.0-py3-none-any.whl (164 kB)
# Using cached linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Using cached markdown-3.10-py3-none-any.whl (107 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdit_py_plugins-0.5.0-py3-none-any.whl (57 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached narwhals-2.10.1-py3-none-any.whl (419 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached xyzservices-2025.10.0-py3-none-any.whl (92 kB)
# Using cached uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Installing collected packages: webencodings, pytz, xyzservices, urllib3, uc-micro-py, tzdata, typing-extensions, tqdm, PyYAML, param, narwhals, mdurl, MarkupSafe, markdown, idna, charset_normalizer, certifi, bleach, requests, pyviz-comms, pandas, markdown-it-py, linkify-it-py, Jinja2, mdit-py-plugins, bokeh, panel
# Successfully installed Jinja2-3.1.6 MarkupSafe-3.0.3 PyYAML-6.0.3 bleach-6.3.0 bokeh-3.8.0 certifi-2025.10.5 charset_normalizer-3.4.4 idna-3.11 linkify-it-py-2.0.3 markdown-3.10 markdown-it-py-4.0.0 mdit-py-plugins-0.5.0 mdurl-0.1.2 narwhals-2.10.1 pandas-2.3.3 panel-1.8.2 param-2.2.1 pytz-2025.2 pyviz-comms-3.0.6 requests-2.32.5 tqdm-4.67.1 typing-extensions-4.15.0 tzdata-2025.2 uc-micro-py-1.0.3 urllib3-2.5.0 webencodings-0.5.1 xyzservices-2025.10.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install panel jupyter_bokeh matplotlib seaborn --upgrade
# Out:
# Requirement already satisfied: panel in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (1.8.2)
# Requirement already satisfied: jupyter_bokeh in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (4.0.5)
# Requirement already satisfied: matplotlib in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: bleach in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (6.3.0)
# Requirement already satisfied: bokeh<3.9.0,>=3.7.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (3.8.0)
# Requirement already satisfied: linkify-it-py in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (2.0.3)
# Requirement already satisfied: markdown in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (3.10)
# Requirement already satisfied: markdown-it-py in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (0.5.0)
# Requirement already satisfied: packaging in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (25.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (2.3.3)
# Requirement already satisfied: param<3.0,>=2.1.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (2.2.1)
# Requirement already satisfied: pyviz-comms>=2.0.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (3.0.6)
# Requirement already satisfied: requests in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from panel) (4.15.0)
# Requirement already satisfied: ipywidgets==8.* in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from jupyter_bokeh) (8.1.8)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (2.10.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (2.3.4)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (12.0.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (6.5.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bokeh<3.9.0,>=3.7.0->panel) (2025.10.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (9.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (3.0.16)
# Requirement already satisfied: cycler>=0.10 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from pandas>=1.2->panel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from pandas>=1.2->panel) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from linkify-it-py->panel) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from markdown-it-py->panel) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from requests->panel) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from requests->panel) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from requests->panel) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from requests->panel) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from tqdm->panel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from Jinja2>=2.9->bokeh<3.9.0,>=3.7.0->panel) (3.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\286116\desktop\ust_python\ust_python_fsd\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.3)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 📦 1. Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import panel as pn
import seaborn as sns

# Initialize Panel extension with all requirements
pn.extension('matplotlib', 'plotly', sizing_mode='stretch_width')

# Set a consistent style
sns.set_style("whitegrid")
plt.style.use('seaborn')
# Out:
# WARNING:param.panel_extension: matplotlib extension not recognized and will be skipped.
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b9cabc29-2015-41fa-90d2-19307d3a7283'>
#   <div id="aea1a993-a3bf-4bc6-a95b-d8945d50e8b3" data-root-id="b9cabc29-2015-41fa-90d2-19307d3a7283" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e157189c-b3b1-4c5c-ba61-493e68c3d473":{"version":"3.8.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"aec816d2-452e-4f97-abbe-0dfee902895e","attributes":{"notifications":{"type":"object","name":"Notifications","id":"40a62afe-194c-48c9-9195-f421537d4688"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"b9cabc29-2015-41fa-90d2-19307d3a7283"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d1eced8d-0ec5-470b-a4e9-776b6aab828b","attributes":{"plot_id":"b9cabc29-2015-41fa-90d2-19307d3a7283","comm_id":"b7096e1ab3904774999206a475d8655e","client_comm_id":"102daeeed30a4fb0b62a32e80d6df487"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"e157189c-b3b1-4c5c-ba61-493e68c3d473","roots":{"b9cabc29-2015-41fa-90d2-19307d3a7283":"aea1a993-a3bf-4bc6-a95b-d8945d50e8b3"},"root_ids":["b9cabc29-2015-41fa-90d2-19307d3a7283"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\286116\Desktop\UST_PYTHON\UST_PYTHON_FSD\venv\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File c:\Users\286116\Desktop\UST_PYTHON\UST_PYTHON_FSD\venv\Lib\site-packages\matplotlib\__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File c:\Users\286116\Desktop\UST_PYTHON\UST_PYTHON_FSD\venv\Lib\site-packages\matplotlib\__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 14
#      12 # Set a consistent style
#      13 sns.set_style("whitegrid")
# ---> 14 plt.style.use('seaborn')
#
# File c:\Users\286116\Desktop\UST_PYTHON\UST_PYTHON_FSD\venv\Lib\site-packages\matplotlib\style\core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
# Load dataset (expects 'heart.csv' to be in the notebook working directory)
# Replace the path if your CSV is located elsewhere
df = pd.read_csv("heart.csv")

df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
# Create filter widgets
sex_filter = pn.widgets.RadioButtonGroup(name='Sex', options=['All', 'Male', 'Female'], value='All')
# Build chest pain options from the dataset so the widget adapts to the CSV
cp_values = sorted(df['ChestPain'].dropna().unique().tolist())
cp_options = ['All'] + [str(v) for v in cp_values]
cp_filter = pn.widgets.Select(name='Chest Pain Type (cp)', options=cp_options, value='All')

sex_filter, cp_filter
# Out:
# (RadioButtonGroup(name='Sex', options=['All', 'Male', 'Female'], value='All'),
#  Select(name='Chest Pain Type (cp)', options=['All', 'asymptomatic', ...], value='All'))

# %%
def filter_data(sex_choice, cp_choice):
    """
    Filters the dataframe based on sex_choice and cp_choice.
    """
    data = df.copy()
    # Filter by sex: dataset uses 1 for male, 0 for female
    if sex_choice != 'All':
        sex_val = 1 if sex_choice == 'Male' else 0
        data = data[data['sex'] == sex_val]
    # Filter by chest pain type
    if cp_choice != 'All':
        try:
            cp_val = int(cp_choice)
            data = data[data['cp'] == cp_val]
        except Exception:
            # If conversion fails, do not filter
            pass
    return data


def plot_dashboard(sex_choice, cp_choice):
    """Return a Matplotlib Figure for the current widget selections."""
    data = filter_data(sex_choice, cp_choice)

    fig, axs = plt.subplots(2, 2, figsize=(12, 8))

    # Chart 1: Age distribution
    axs[0, 0].hist(data['Age'].dropna(), bins=15, color='#4C72B0', edgecolor='black')
    axs[0, 0].set_title('Age Distribution')
    axs[0, 0].set_xlabel('Age')
    axs[0, 0].set_ylabel('Count')

    # Chart 2: Average Cholesterol by Heart Disease Target
    if 'chol' in data.columns and 'target' in data.columns:
        chol_mean = data.groupby('target')['chol'].mean().reindex([0, 1])
        chol_mean_na = chol_mean.fillna(0)
        axs[0, 1].bar(['No Disease', 'Disease'], chol_mean_na, color=['#55A868', '#C44E52'])
        axs[0, 1].set_title('Average Cholesterol by Heart Disease')
        axs[0, 1].set_ylabel('Mean Cholesterol')
    else:
        axs[0, 1].text(0.5, 0.5, 'chol or target column missing', ha='center')
        axs[0, 1].set_axis_off()

    # Chart 3: Resting Blood Pressure distribution
    if 'trestbps' in data.columns:
        axs[1, 0].hist(data['trestbps'].dropna(), bins=15, color='#8172B2', edgecolor='black')
        axs[1, 0].set_title('Resting Blood Pressure Distribution')
        axs[1, 0].set_xlabel('Resting BP')
        axs[1, 0].set_ylabel('Count')
    else:
        axs[1, 0].text(0.5, 0.5, 'trestbps column missing', ha='center')
        axs[1, 0].set_axis_off()

    # Chart 4: Heart Disease case counts
    if 'target' in data.columns:
        counts = data['target'].value_counts().reindex([0, 1]).fillna(0)
        axs[1, 1].bar(['No Disease', 'Disease'], counts, color=['#2E91E5', '#E15F99'])
        axs[1, 1].set_title('Heart Disease Case Counts')
        axs[1, 1].set_ylabel('Count')
    else:
        axs[1, 1].text(0.5, 0.5, 'target column missing', ha='center')
        axs[1, 1].set_axis_off()

    plt.tight_layout()
    return fig

# %%
# Create the dashboard with explicit sizing
dashboard = pn.Column(
    '# ❤️ Heart Disease Interactive Dashboard',
    pn.Row(sex_filter, cp_filter),
    pn.pane.Matplotlib(
        pn.bind(plot_dashboard, sex_choice=sex_filter, cp_choice=cp_filter),
        height=600,
        width=800
    ),
    sizing_mode='stretch_width'
)

# Display the dashboard
dashboard.show()
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'417aa9bc-751f-4b0b-8929-fc5b5ec3454e': {'version…
