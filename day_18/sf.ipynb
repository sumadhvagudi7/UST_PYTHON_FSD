# %%
##SF Salaries Exercise
""" Welcome to a quick exe/rcise for you to practice your pandas skills! We will be using the SF Salaries Dataset from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

** Import pandas as pd.** """

# %%
import pandas as pd

# %%
# -----------------------------------------------
# 2. Read Salaries.csv as a dataframe called sal
# -----------------------------------------------
sal = pd.read_csv("Salaries.csv")

# %%
# -----------------------------------------------
# 3. Check the head of the DataFrame
# -----------------------------------------------
sal.head()
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                   CAPTAIN III (POLICE DEPARTMENT)
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 11  12    PATRICIA JACKSON                   CAPTAIN III (POLICE DEPARTMENT)
# 12  13   EDWARD HARRINGTON                       EXECUTIVE CONTRACT EMPLOYEE
# 13  14         JOHN MARTIN                                 DEPARTMENT HEAD V
# 14  15      DAVID FRANKLIN                BATTALION CHIEF, (FIRE DEPARTMENT)
# 15  16     RICHARD CORRIEA                COMMANDER III, (POLICE DEPARTMENT)
# 16  17            AMY HART                                 DEPARTMENT HEAD V
# 17  18      SEBASTIAN WONG             CAPTAIN, EMERGENCYCY MEDICAL SERVICES
# 18  19          MARTY ROSS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 19  20       ELLEN MOFFATT                        ASSISTANT MEDICAL EXAMINER
# 20  21          VENUS AZAR                        ASSISTANT MEDICAL EXAMINER
# 21  22        JUDY MELINEK                        ASSISTANT MEDICAL EXAMINER
# 22  23       GEORGE GARCIA                         CAPTAIN, FIRE SUPPRESSION
# 23  24       VICTOR WYRSCH                BATTALION CHIEF, (FIRE DEPARTMENT)
#
#       BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0   167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1   155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2   212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3    77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4   134401.60      9737.00  182234.59       NaN  326373.19         326373.19
# 5   118602.00      8601.00  189082.74       NaN  316285.74         316285.74
# 6    92492.01     89062.90  134426.14       NaN  315981.05         315981.05
# 7   256576.96         0.00   51322.50       NaN  307899.46         307899.46
# 8   176932.64     86362.68   40132.23       NaN  303427.55         303427.55
# 9   285262.00         0.00   17115.73       NaN  302377.73         302377.73
# 10  194999.39     71344.88   33149.90       NaN  299494.17         299494.17
# 11   99722.00     87082.62  110804.30       NaN  297608.92         297608.92
# 12  294580.02         0.00       0.00       NaN  294580.02         294580.02
# 13  271329.03         0.00   21342.59       NaN  292671.62         292671.62
# 14  174872.64     74050.30   37424.11       NaN  286347.05         286347.05
# 15  198778.01     73478.20   13957.65       NaN  286213.86         286213.86
# 16  268604.57         0.00   16115.86       NaN  284720.43         284720.43
# 17  140546.87    119397.26   18625.08       NaN  278569.21         278569.21
# 18  168692.63     69626.12   38115.47       NaN  276434.22         276434.22
# 19  257510.59       880.16   16159.50       NaN  274550.25         274550.25
# 20  257510.48         0.00   16679.79       NaN  274190.27         274190.27
# 21  257510.44       377.21   15883.56       NaN  273771.21         273771.21
# 22  140546.88     93200.58   39955.25       NaN  273702.71         273702.71
# 23  168692.63     77896.14   24083.86       NaN  270672.63         270672.63
#
#     Year  Notes         Agency  Status  title_len
# 0   2011    NaN  San Francisco     NaN         46
# 1   2011    NaN  San Francisco     NaN         31
# 2   2011    NaN  San Francisco     NaN         31
# 3   2011    NaN  San Francisco     NaN         36
# 4   2011    NaN  San Francisco     NaN         44
# 5   2011    NaN  San Francisco     NaN         25
# 6   2011    NaN  San Francisco     NaN         34
# 7   2011    NaN  San Francisco     NaN         30
# 8   2011    NaN  San Francisco     NaN         34
# 9   2011    NaN  San Francisco     NaN         38
# 10  2011    NaN  San Francisco     NaN         48
# 11  2011    NaN  San Francisco     NaN         31
# 12  2011    NaN  San Francisco     NaN         27
# 13  2011    NaN  San Francisco     NaN         17
# 14  2011    NaN  San Francisco     NaN         34
# 15  2011    NaN  San Francisco     NaN         34
# 16  2011    NaN  San Francisco     NaN         17
# 17  2011    NaN  San Francisco     NaN         37
# 18  2011    NaN  San Francisco     NaN         34
# 19  2011    NaN  San Francisco     NaN         26
# 20  2011    NaN  San Francisco     NaN         26
# 21  2011    NaN  San Francisco     NaN         26
# 22  2011    NaN  San Francisco     NaN         25
# 23  2011    NaN  San Francisco     NaN         34

# %%
# 4. Use the .info() method to find out how many entries there are
# -----------------------------------------------
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
# -----------------------------------------------
# 5. What is the average BasePay?
# -----------------------------------------------
sal['BasePay'].mean()
# Out:
# np.float64(66325.44884048769)

# %%
# -----------------------------------------------
# 6. What is the highest amount of OvertimePay in the dataset?
# -----------------------------------------------
sal['OvertimePay'].max()
# Out:
# np.float64(245131.88)

# %%
# 7. What is the job title of JOSEPH DRISCOLL?
# -----------------------------------------------
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
# -----------------------------------------------
# 8. How much does JOSEPH DRISCOLL make (including benefits)?
# -----------------------------------------------
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
# -----------------------------------------------
# 9. What is the name of highest paid person (including benefits)?

sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
# 10. What is the name of lowest paid person (including benefits)?

sal[sal['TotalPayBenefits'] == sal['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
# 11. What was the average (mean) BasePay of all employees per year (2011-2014)?
sal.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
# 12. How many unique job titles are there?

sal['JobTitle'].nunique()
# Out:
# 2159

# %%
# 13. What are the top 5 most common jobs?
sal['JobTitle'].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
# 14. How many Job Titles were represented by only one person in 2013?
sum(sal[sal['Year'] == 2013]['JobTitle'].value_counts() == 1)
# Out:
# 202

# %%
# 15. How many people have the word 'Chief' in their job title?
sum(sal['JobTitle'].apply(lambda x: 'chief' in x.lower()))
# Out:
# 627

# %%
# -----------------------------------------------
# 16. Bonus: Is there a correlation between the length of the Job Title string and Salary?
# -----------------------------------------------
sal['title_len'] = sal['JobTitle'].apply(len)
sal[['title_len', 'TotalPayBenefits']].corr()
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000
